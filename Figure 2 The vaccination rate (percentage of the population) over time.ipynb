# %% [markdown]
# # Import important Libraries¶

# %%
# Here we are using libraries

# %%
import pandas as pd
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt

import seaborn as sns

import plotly.graph_objects as go

#import folium
 
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot, init_notebook_mode



init_notebook_mode(connected=True) 
import chart_studio.plotly as py
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ## DATA Set loading for visualization

# %%
url="https://covid.ourworldindata.org/data/owid-covid-data.csv"

# %%
df_country_info = pd.read_csv(url, sep=',')

# %% [markdown]
# ## Viewing columns of dataset

# %%
df_country_info.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'total_tests', 'new_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'total_boosters',
# ...

# %% [markdown]
# ## Seeing data in first 5 rows using .head()

# %%
df_country_info.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1      AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    female_smokers  male_smokers  handwashing_facilities  \
# ...

# %%
df_country_info.to_csv('covid_full_data.csv', ';')

# %% [markdown]
# #### List of countries in the dataset

# %%
df_country_info['location'].unique()
# Out:
# array(['Afghanistan', 'Africa', 'Albania', 'Algeria', 'Andorra', 'Angola',
#        'Anguilla', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba',
#        'Asia', 'Australia', 'Austria', 'Azerbaijan', 'Bahamas', 'Bahrain',
#        'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin',
#        'Bermuda', 'Bhutan', 'Bolivia', 'Bonaire Sint Eustatius and Saba',
#        'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'British Virgin Islands', 'Brunei', 'Bulgaria', 'Burkina Faso',
#        'Burundi', 'Cambodia', 'Cameroon', 'Canada', 'Cape Verde',
#        'Cayman Islands', 'Central African Republic', 'Chad', 'Chile',
#        'China', 'Colombia', 'Comoros', 'Congo', 'Cook Islands',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Curacao',
#        'Cyprus', 'Czechia', 'Democratic Republic of Congo', 'Denmark',
#        'Djibouti', 'Dominica', 'Dominican Republic', 'Ecuador', 'Egypt',
# ...

# %%
df_IND = df_country_info[df_country_info['location']=='India']

# %%
df_IND
# Out:
#       iso_code continent location        date  total_cases  new_cases  \
# 81546      IND      Asia    India  2020-01-30          1.0        1.0
# 81547      IND      Asia    India  2020-01-31          1.0        0.0
# 81548      IND      Asia    India  2020-02-01          1.0        0.0
# 81549      IND      Asia    India  2020-02-02          2.0        1.0
# 81550      IND      Asia    India  2020-02-03          3.0        1.0
# ...        ...       ...      ...         ...          ...        ...
# 82422      IND      Asia    India  2022-06-24   43378234.0    15940.0
# 82423      IND      Asia    India  2022-06-25   43389973.0    11739.0
# 82424      IND      Asia    India  2022-06-26   43407046.0    17073.0
# 82425      IND      Asia    India  2022-06-27   43418839.0    11793.0
# 82426      IND      Asia    India  2022-06-28   43433345.0    14506.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %% [markdown]
# #### Reset the index

# %%
df_IND .reset_index()
# Out:
#      index iso_code continent location        date  total_cases  new_cases  \
# 0    81546      IND      Asia    India  2020-01-30          1.0        1.0
# 1    81547      IND      Asia    India  2020-01-31          1.0        0.0
# 2    81548      IND      Asia    India  2020-02-01          1.0        0.0
# 3    81549      IND      Asia    India  2020-02-02          2.0        1.0
# 4    81550      IND      Asia    India  2020-02-03          3.0        1.0
# ..     ...      ...       ...      ...         ...          ...        ...
# 876  82422      IND      Asia    India  2022-06-24   43378234.0    15940.0
# 877  82423      IND      Asia    India  2022-06-25   43389973.0    11739.0
# 878  82424      IND      Asia    India  2022-06-26   43407046.0    17073.0
# 879  82425      IND      Asia    India  2022-06-27   43418839.0    11793.0
# 880  82426      IND      Asia    India  2022-06-28   43433345.0    14506.0
#
# ...

# %% [markdown]
# #### Droping the index column

# %%
df_IND.reset_index(drop=True)
# Out:
#     iso_code continent location        date  total_cases  new_cases  \
# 0        IND      Asia    India  2020-01-30          1.0        1.0
# 1        IND      Asia    India  2020-01-31          1.0        0.0
# 2        IND      Asia    India  2020-02-01          1.0        0.0
# 3        IND      Asia    India  2020-02-02          2.0        1.0
# 4        IND      Asia    India  2020-02-03          3.0        1.0
# ..       ...       ...      ...         ...          ...        ...
# 876      IND      Asia    India  2022-06-24   43378234.0    15940.0
# 877      IND      Asia    India  2022-06-25   43389973.0    11739.0
# 878      IND      Asia    India  2022-06-26   43407046.0    17073.0
# 879      IND      Asia    India  2022-06-27   43418839.0    11793.0
# 880      IND      Asia    India  2022-06-28   43433345.0    14506.0
#
#      new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %%
df_IND = df_IND.reset_index(drop=True)

# %%
import missingno as msno

# %%
msno.matrix(df_IND)
# Out:
# <AxesSubplot:>

# %%
msno.matrix(df_IND[['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
       'new_cases_smoothed', 'total_deaths', 'new_deaths',
       'new_deaths_smoothed', 'total_cases_per_million',
       'new_cases_per_million', 'new_cases_smoothed_per_million',
       'total_deaths_per_million', 'new_deaths_per_million',
       'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
       'icu_patients_per_million', 'hosp_patients']])
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Basic Plotting line chart example

# %%
df_IND.head()
# Out:
#   iso_code continent location        date  total_cases  new_cases  \
# 0      IND      Asia    India  2020-01-30          1.0        1.0
# 1      IND      Asia    India  2020-01-31          1.0        0.0
# 2      IND      Asia    India  2020-02-01          1.0        0.0
# 3      IND      Asia    India  2020-02-02          2.0        1.0
# 4      IND      Asia    India  2020-02-03          3.0        1.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    female_smokers  male_smokers  handwashing_facilities  \
# 0             1.9          20.6                   59.55
# ...

# %% [markdown]
# #### Ploting the total people vaccinated of India over time

# %%
import plotly.express as px
fig = px.line(df_IND, x="date", y="people_vaccinated", title='Vaccinated People')
fig.show()
# Out:
# <div>                            <div id="47dfb04c-d7da-49ff-9051-3705497017c9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("47dfb04c-d7da-49ff-9051-3705497017c9")) {                    Plotly.newPlot(                        "47dfb04c-d7da-49ff-9051-3705497017c9",                        [{"hovertemplate":"date=%{x}<br>people_vaccinated=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["2020-01-30","2020-01-31","2020-02-01","2020-02-02","2020-02-03","2020-02-04","2020-02-05","2020-02-06","2020-02-07","2020-02-08","2020-02-09","2020-02-10","2020-02-11","2020-02-12","2020-02-13","2020-02-14","2020-02-15","2020-02-16","2020-02
# ...

# %% [markdown]
# Vaccinated_people/population_size

# %% [markdown]
# ### Diving the total cases of India by its population

# %%
df_IND['people_vaccinated']/df_IND['population']
# Out:
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
#          ...
# 876    0.728755
# 877    0.728906
# 878    0.729013
# 879    0.729059
# 880    0.729233
# Length: 881, dtype: float64

# %%
df_IND['people_vaccinated']/1300000000
# Out:
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
#          ...
# 876    0.781118
# 877    0.781280
# 878    0.781394
# 879    0.781445
# 880    0.781630
# Name: people_vaccinated, Length: 881, dtype: float64

# %%
#country_list = ['India','Germany','Italy','United States','Spain']

# %%
# df_con = []
# for each in country_list:
#     df_c = df_country_info['location']== each
#     df_con.append(df_c)

# %%
# df_con

# %%
# any(df_con)

# %%
# sum(df_con)

# %%
b_IND=df_country_info['location']=='India'
b_GER=df_country_info['location']=='Germany'
b_ITY=df_country_info['location']=='Italy'
b_SPN=df_country_info['location']=='Spain'
b_US=df_country_info['location'] == 'United States'

# %%
sum(b_IND)
# Out:
# 881

# %%
sum(b_GER)
# Out:
# 884

# %%
sum(b_IND | b_GER | b_ITY | b_SPN | b_US)
# Out:
# 4413

# %%
b_all = b_IND | b_GER | b_ITY | b_SPN | b_US

# %%
sum(b_all)
# Out:
# 4413

# %%
b_all
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 197460    False
# 197461    False
# 197462    False
# 197463    False
# 197464    False
# Name: location, Length: 197465, dtype: bool

# %%
df_my_list = df_country_info[b_all]

# %%
df_my_list
# Out:
#        iso_code      continent       location        date  total_cases  \
# 66594       DEU         Europe        Germany  2020-01-27          1.0
# 66595       DEU         Europe        Germany  2020-01-28          4.0
# 66596       DEU         Europe        Germany  2020-01-29          4.0
# 66597       DEU         Europe        Germany  2020-01-30          4.0
# 66598       DEU         Europe        Germany  2020-01-31          5.0
# ...         ...            ...            ...         ...          ...
# 186931      USA  North America  United States  2022-06-24   86909476.0
# 186932      USA  North America  United States  2022-06-25   86948848.0
# 186933      USA  North America  United States  2022-06-26   86967399.0
# 186934      USA  North America  United States  2022-06-27   87092233.0
# 186935      USA  North America  United States  2022-06-28   87217673.0
#
#         new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# ...

# %% [markdown]
# ### Linear Graph People vaccinated over time for five countries

# %%
fig = px.line(df_my_list, x="date", y="people_vaccinated", color ='location', title='People Vaccinated')
fig.show()
# Out:
# <div>                            <div id="3de19f30-a0d4-4c0b-99ba-21a97fb22205" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3de19f30-a0d4-4c0b-99ba-21a97fb22205")) {                    Plotly.newPlot(                        "3de19f30-a0d4-4c0b-99ba-21a97fb22205",                        [{"hovertemplate":"location=Germany<br>date=%{x}<br>people_vaccinated=%{y}<extra></extra>","legendgroup":"Germany","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Germany","showlegend":true,"x":["2020-01-27","2020-01-28","2020-01-29","2020-01-30","2020-01-31","2020-02-01","2020-02-02","2020-02-03","2020-02-04","2020-02-05","2020-02-06","2020-02-07","2020-02-08","2020-02-09","2020-02-10","2020-02-11","2020-02-12","2020-
# ...

# %%
df_plot1 = df_my_list[(df_my_list['date']>'2020-11-01')]

# %%
fig = px.line(df_plot1, x="date", y="people_vaccinated", color ='location', title='Linear Graph of People Vaccinated')
fig.show()
# Out:
# <div>                            <div id="e4bf0d72-2bec-4224-b51b-4e1ffe5aa02d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e4bf0d72-2bec-4224-b51b-4e1ffe5aa02d")) {                    Plotly.newPlot(                        "e4bf0d72-2bec-4224-b51b-4e1ffe5aa02d",                        [{"hovertemplate":"location=Germany<br>date=%{x}<br>people_vaccinated=%{y}<extra></extra>","legendgroup":"Germany","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Germany","showlegend":true,"x":["2020-11-02","2020-11-03","2020-11-04","2020-11-05","2020-11-06","2020-11-07","2020-11-08","2020-11-09","2020-11-10","2020-11-11","2020-11-12","2020-11-13","2020-11-14","2020-11-15","2020-11-16","2020-11-17","2020-11-18","2020-
# ...

# %%
df_my_list['people_vaccination_ratio_in_%'] = (df_my_list['people_vaccinated']/df_my_list['population'])*100
# Out:
# C:\Users\pandh\AppData\Local\Temp\ipykernel_6612\1379569675.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# ###  Figure 2 The vaccination rate (percentage of the population) over time in percentage

# %%
fig = px.line(df_plot1, x="date", y='people_vaccination_ratio_in_%', color ='location', title='Vaccination rate in %')
fig.show()
# Out:
# <div>                            <div id="ab46e766-9651-4abf-b741-4ad7722c2df2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ab46e766-9651-4abf-b741-4ad7722c2df2")) {                    Plotly.newPlot(                        "ab46e766-9651-4abf-b741-4ad7722c2df2",                        [{"hovertemplate":"location=Germany<br>date=%{x}<br>people_vaccination_ratio_in_%=%{y}<extra></extra>","legendgroup":"Germany","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Germany","showlegend":true,"x":["2020-11-02","2020-11-03","2020-11-04","2020-11-05","2020-11-06","2020-11-07","2020-11-08","2020-11-09","2020-11-10","2020-11-11","2020-11-12","2020-11-13","2020-11-14","2020-11-15","2020-11-16","2020-11-17","2020-1
# ...

# %% [markdown]
# ## Logarithmic Graph : The vaccination rate (percentage of the population) over time in percentage

# %%
fig = px.line(df_plot1, x="date", y='people_vaccination_ratio_in_%', color ='location', title='Logarithmic Graph of Vaccination rate w.r.t. population in percentage')
fig.update_layout(yaxis_type="log")
fig.show()
# Out:
# <div>                            <div id="c09630f4-3509-4af5-9801-88536719ad44" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c09630f4-3509-4af5-9801-88536719ad44")) {                    Plotly.newPlot(                        "c09630f4-3509-4af5-9801-88536719ad44",                        [{"hovertemplate":"location=Germany<br>date=%{x}<br>people_vaccination_ratio_in_%=%{y}<extra></extra>","legendgroup":"Germany","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Germany","showlegend":true,"x":["2020-11-02","2020-11-03","2020-11-04","2020-11-05","2020-11-06","2020-11-07","2020-11-08","2020-11-09","2020-11-10","2020-11-11","2020-11-12","2020-11-13","2020-11-14","2020-11-15","2020-11-16","2020-11-17","2020-1
# ...

# %%
df_my_list.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'total_tests', 'new_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'total_boosters',
# ...

# %% [markdown]
# # Plotting the people vaccinated w.r.t. population  in percentage on a World Map

# %%
data = dict(type='choropleth',
            colorscale = 'Viridis',
            reversescale = True,
           locations = df_my_list['location'],
            locationmode = "country names",
           z = df_my_list['people_vaccination_ratio_in_%'],
           text = df_my_list['location'],
           colorbar = {'title' : 'Vaccination rate of countries with respect to population in percentage'},
           
           
           )

# %%
layout = dict(title = 'COVID 19 Vaccination rate distribution of total cases w.r.t population in %',
                geo = dict(showframe = False,projection = {'type':'mercator'})
             )

# %%
choromap = go.Figure(data = [data],layout = layout)
iplot(choromap,validate=False)
# Out:
# <div>                            <div id="47c48a98-cff6-479e-9a69-59bc56b386fd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("47c48a98-cff6-479e-9a69-59bc56b386fd")) {                    Plotly.newPlot(                        "47c48a98-cff6-479e-9a69-59bc56b386fd",                        [{"colorbar":{"title":{"text":"Vaccination rate of countries with respect to population in percentage"}},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"locationmode":"country names","locations":["Germany","Germany","Ger
# ...
